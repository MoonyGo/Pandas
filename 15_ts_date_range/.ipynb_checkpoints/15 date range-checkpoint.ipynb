# %%
import pandas as pd
df=pd.read_csv("aapl_no_dates.csv")

# %%
df.head()
# Out:
#      Open    High     Low   Close    Volume
# 0  153.17  153.33  152.22  153.18  16404088
# 1  153.58  155.45  152.89  155.45  27770715
# 2  154.34  154.45  153.46  153.93  25331662
# 3  153.90  155.81  153.78  154.45  26624926
# 4  155.02  155.98  154.48  155.37  21069647

# %% [markdown]
# freq='B'는 business days which would exclude business days

# %% [markdown]
# pd.date_range를 하면 DatetimeIndex가 생성됨

# %%
rng=pd.date_range(start="6/1/2017", end="6/30/2017",freq='B')

# %%
df.set_index(rng)
df
# Out:
#       Open    High     Low   Close    Volume
# 0   153.17  153.33  152.22  153.18  16404088
# 1   153.58  155.45  152.89  155.45  27770715
# 2   154.34  154.45  153.46  153.93  25331662
# 3   153.90  155.81  153.78  154.45  26624926
# 4   155.02  155.98  154.48  155.37  21069647
# 5   155.25  155.54  154.40  154.99  21250798
# 6   155.19  155.19  146.02  148.98  64882657
# 7   145.74  146.09  142.51  145.42  72307330
# 8   147.16  147.45  145.15  146.59  34165445
# 9   147.50  147.50  143.84  145.16  31531232
# 10  143.32  144.48  142.21  144.29  32165373
# 11  143.78  144.50  142.20  142.27  50361093
# 12  143.66  146.74  143.66  146.34  32541404
# 13  146.87  146.87  144.94  145.01  24900073
# 14  145.52  146.07  144.61  145.87  21265751
# 15  145.77  146.70  145.12  145.63  19106294
# 16  145.13  147.16  145.11  146.28  35439389
# 17  147.17  148.28  145.38  145.82  25692361
# 18  145.01  146.16  143.62  143.73  24761891
# 19  144.49  146.11  143.16  145.83  22082432
# ...

# %%
df.set_index(rng, inplace=True)
df
# Out:
#               Open    High     Low   Close    Volume
# 2017-06-01  153.17  153.33  152.22  153.18  16404088
# 2017-06-02  153.58  155.45  152.89  155.45  27770715
# 2017-06-05  154.34  154.45  153.46  153.93  25331662
# 2017-06-06  153.90  155.81  153.78  154.45  26624926
# 2017-06-07  155.02  155.98  154.48  155.37  21069647
# 2017-06-08  155.25  155.54  154.40  154.99  21250798
# 2017-06-09  155.19  155.19  146.02  148.98  64882657
# 2017-06-12  145.74  146.09  142.51  145.42  72307330
# 2017-06-13  147.16  147.45  145.15  146.59  34165445
# 2017-06-14  147.50  147.50  143.84  145.16  31531232
# 2017-06-15  143.32  144.48  142.21  144.29  32165373
# 2017-06-16  143.78  144.50  142.20  142.27  50361093
# 2017-06-19  143.66  146.74  143.66  146.34  32541404
# 2017-06-20  146.87  146.87  144.94  145.01  24900073
# 2017-06-21  145.52  146.07  144.61  145.87  21265751
# 2017-06-22  145.77  146.70  145.12  145.63  19106294
# 2017-06-23  145.13  147.16  145.11  146.28  35439389
# ...

# %% [markdown]
# inplace=true를 해야

# %%
df.set_index(rng, inplace=True)
df
# Out:
#               Open    High     Low   Close    Volume
# 2017-06-01  153.17  153.33  152.22  153.18  16404088
# 2017-06-02  153.58  155.45  152.89  155.45  27770715
# 2017-06-05  154.34  154.45  153.46  153.93  25331662
# 2017-06-06  153.90  155.81  153.78  154.45  26624926
# 2017-06-07  155.02  155.98  154.48  155.37  21069647
# 2017-06-08  155.25  155.54  154.40  154.99  21250798
# 2017-06-09  155.19  155.19  146.02  148.98  64882657
# 2017-06-12  145.74  146.09  142.51  145.42  72307330
# 2017-06-13  147.16  147.45  145.15  146.59  34165445
# 2017-06-14  147.50  147.50  143.84  145.16  31531232
# 2017-06-15  143.32  144.48  142.21  144.29  32165373
# 2017-06-16  143.78  144.50  142.20  142.27  50361093
# 2017-06-19  143.66  146.74  143.66  146.34  32541404
# 2017-06-20  146.87  146.87  144.94  145.01  24900073
# 2017-06-21  145.52  146.07  144.61  145.87  21265751
# 2017-06-22  145.77  146.70  145.12  145.63  19106294
# 2017-06-23  145.13  147.16  145.11  146.28  35439389
# ...

# %%
# %matplotlib inline
df.Close.plot()

# %%
df=pd.read_csv('aapl_no_dates.csv')
df
# Out:
#       Open    High     Low   Close    Volume
# 0   153.17  153.33  152.22  153.18  16404088
# 1   153.58  155.45  152.89  155.45  27770715
# 2   154.34  154.45  153.46  153.93  25331662
# 3   153.90  155.81  153.78  154.45  26624926
# 4   155.02  155.98  154.48  155.37  21069647
# 5   155.25  155.54  154.40  154.99  21250798
# 6   155.19  155.19  146.02  148.98  64882657
# 7   145.74  146.09  142.51  145.42  72307330
# 8   147.16  147.45  145.15  146.59  34165445
# 9   147.50  147.50  143.84  145.16  31531232
# 10  143.32  144.48  142.21  144.29  32165373
# 11  143.78  144.50  142.20  142.27  50361093
# 12  143.66  146.74  143.66  146.34  32541404
# 13  146.87  146.87  144.94  145.01  24900073
# 14  145.52  146.07  144.61  145.87  21265751
# 15  145.77  146.70  145.12  145.63  19106294
# 16  145.13  147.16  145.11  146.28  35439389
# 17  147.17  148.28  145.38  145.82  25692361
# 18  145.01  146.16  143.62  143.73  24761891
# 19  144.49  146.11  143.16  145.83  22082432
# ...

# %%
rng=pd.date_range(start='2010/01/01',end='2010/01/22')

# %%
df.set_index(rng)
# Out:
#               Open    High     Low   Close    Volume
# 2010-01-01  153.17  153.33  152.22  153.18  16404088
# 2010-01-02  153.58  155.45  152.89  155.45  27770715
# 2010-01-03  154.34  154.45  153.46  153.93  25331662
# 2010-01-04  153.90  155.81  153.78  154.45  26624926
# 2010-01-05  155.02  155.98  154.48  155.37  21069647
# 2010-01-06  155.25  155.54  154.40  154.99  21250798
# 2010-01-07  155.19  155.19  146.02  148.98  64882657
# 2010-01-08  145.74  146.09  142.51  145.42  72307330
# 2010-01-09  147.16  147.45  145.15  146.59  34165445
# 2010-01-10  147.50  147.50  143.84  145.16  31531232
# 2010-01-11  143.32  144.48  142.21  144.29  32165373
# 2010-01-12  143.78  144.50  142.20  142.27  50361093
# 2010-01-13  143.66  146.74  143.66  146.34  32541404
# 2010-01-14  146.87  146.87  144.94  145.01  24900073
# 2010-01-15  145.52  146.07  144.61  145.87  21265751
# 2010-01-16  145.77  146.70  145.12  145.63  19106294
# 2010-01-17  145.13  147.16  145.11  146.28  35439389
# ...

# %%
df.reset_index(rng, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-211be5827f8b> in <module>()
# ----> 1 df.reset_index(rng, inplace=True)
#
# /anaconda3/envs/nextopt/lib/python3.6/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4099             if not isinstance(level, (tuple, list)):
#    4100                 level = [level]
# -> 4101             level = [self.index._get_level_number(lev) for lev in level]
#    4102             if isinstance(self.index, MultiIndex):
#    4103                 if len(level) < self.index.nlevels:
#
# /anaconda3/envs/nextopt/lib/python3.6/site-packages/pandas/core/frame.py in <listcomp>(.0)
#    4099             if not isinstance(level, (tuple, list)):
#    4100                 level = [level]
# -> 4101             level = [self.index._get_level_number(lev) for lev in level]
# ...

# %%
# %matplotlib inline
df.Close.plot()

# %%
df
# Out:
#       Open    High     Low   Close    Volume
# 0   153.17  153.33  152.22  153.18  16404088
# 1   153.58  155.45  152.89  155.45  27770715
# 2   154.34  154.45  153.46  153.93  25331662
# 3   153.90  155.81  153.78  154.45  26624926
# 4   155.02  155.98  154.48  155.37  21069647
# 5   155.25  155.54  154.40  154.99  21250798
# 6   155.19  155.19  146.02  148.98  64882657
# 7   145.74  146.09  142.51  145.42  72307330
# 8   147.16  147.45  145.15  146.59  34165445
# 9   147.50  147.50  143.84  145.16  31531232
# 10  143.32  144.48  142.21  144.29  32165373
# 11  143.78  144.50  142.20  142.27  50361093
# 12  143.66  146.74  143.66  146.34  32541404
# 13  146.87  146.87  144.94  145.01  24900073
# 14  145.52  146.07  144.61  145.87  21265751
# 15  145.77  146.70  145.12  145.63  19106294
# 16  145.13  147.16  145.11  146.28  35439389
# 17  147.17  148.28  145.38  145.82  25692361
# 18  145.01  146.16  143.62  143.73  24761891
# 19  144.49  146.11  143.16  145.83  22082432
# ...

# %%
df=pd.read_csv('aapl_no_dates.csv')

# %%
rng=pd.date_range(start='2017-06-01',end='2017-06-30',freq='B')

# %%
df.set_index(rng, inplace=True)

# %%
df
# Out:
#               Open    High     Low   Close    Volume
# 2017-06-01  153.17  153.33  152.22  153.18  16404088
# 2017-06-02  153.58  155.45  152.89  155.45  27770715
# 2017-06-05  154.34  154.45  153.46  153.93  25331662
# 2017-06-06  153.90  155.81  153.78  154.45  26624926
# 2017-06-07  155.02  155.98  154.48  155.37  21069647
# 2017-06-08  155.25  155.54  154.40  154.99  21250798
# 2017-06-09  155.19  155.19  146.02  148.98  64882657
# 2017-06-12  145.74  146.09  142.51  145.42  72307330
# 2017-06-13  147.16  147.45  145.15  146.59  34165445
# 2017-06-14  147.50  147.50  143.84  145.16  31531232
# 2017-06-15  143.32  144.48  142.21  144.29  32165373
# 2017-06-16  143.78  144.50  142.20  142.27  50361093
# 2017-06-19  143.66  146.74  143.66  146.34  32541404
# 2017-06-20  146.87  146.87  144.94  145.01  24900073
# 2017-06-21  145.52  146.07  144.61  145.87  21265751
# 2017-06-22  145.77  146.70  145.12  145.63  19106294
# 2017-06-23  145.13  147.16  145.11  146.28  35439389
# ...

# %%
df['2017-06-01':'2017-06-10'].Close.mean()
# Out:
# 153.7642857142857

# %%
df['2017-06-01':'2017-06-10'].Close
# Out:
# 2017-06-01    153.18
# 2017-06-02    155.45
# 2017-06-05    153.93
# 2017-06-06    154.45
# 2017-06-07    155.37
# 2017-06-08    154.99
# 2017-06-09    148.98
# Freq: B, Name: Close, dtype: float64

# %% [markdown]
# 중간에 주말같은 날은 빠져있는데, 이를 채워줌 (asfrea='D'로 하고, method='pad'로 하면 채워짐)

# %%
df.asfreq('D',method='pad')
# Out:
#               Open    High     Low   Close    Volume
# 2017-06-01  153.17  153.33  152.22  153.18  16404088
# 2017-06-02  153.58  155.45  152.89  155.45  27770715
# 2017-06-03  153.58  155.45  152.89  155.45  27770715
# 2017-06-04  153.58  155.45  152.89  155.45  27770715
# 2017-06-05  154.34  154.45  153.46  153.93  25331662
# 2017-06-06  153.90  155.81  153.78  154.45  26624926
# 2017-06-07  155.02  155.98  154.48  155.37  21069647
# 2017-06-08  155.25  155.54  154.40  154.99  21250798
# 2017-06-09  155.19  155.19  146.02  148.98  64882657
# 2017-06-10  155.19  155.19  146.02  148.98  64882657
# 2017-06-11  155.19  155.19  146.02  148.98  64882657
# 2017-06-12  145.74  146.09  142.51  145.42  72307330
# 2017-06-13  147.16  147.45  145.15  146.59  34165445
# 2017-06-14  147.50  147.50  143.84  145.16  31531232
# 2017-06-15  143.32  144.48  142.21  144.29  32165373
# 2017-06-16  143.78  144.50  142.20  142.27  50361093
# 2017-06-17  143.78  144.50  142.20  142.27  50361093
# ...

# %%
rng = pd.date_range(start="1/1/2017", periods=22,freq='d')

# %%
df.set_index(rng, inplace=True)

# %%
df
# Out:
#               Open    High     Low   Close    Volume
# 2017-01-01  153.17  153.33  152.22  153.18  16404088
# 2017-01-02  153.58  155.45  152.89  155.45  27770715
# 2017-01-03  154.34  154.45  153.46  153.93  25331662
# 2017-01-04  153.90  155.81  153.78  154.45  26624926
# 2017-01-05  155.02  155.98  154.48  155.37  21069647
# 2017-01-06  155.25  155.54  154.40  154.99  21250798
# 2017-01-07  155.19  155.19  146.02  148.98  64882657
# 2017-01-08  145.74  146.09  142.51  145.42  72307330
# 2017-01-09  147.16  147.45  145.15  146.59  34165445
# 2017-01-10  147.50  147.50  143.84  145.16  31531232
# 2017-01-11  143.32  144.48  142.21  144.29  32165373
# 2017-01-12  143.78  144.50  142.20  142.27  50361093
# 2017-01-13  143.66  146.74  143.66  146.34  32541404
# 2017-01-14  146.87  146.87  144.94  145.01  24900073
# 2017-01-15  145.52  146.07  144.61  145.87  21265751
# 2017-01-16  145.77  146.70  145.12  145.63  19106294
# 2017-01-17  145.13  147.16  145.11  146.28  35439389
# ...

# %%
import numpy as np
np.random.randint(1,10,len(rng))
# Out:
# array([2, 6, 2, 9, 5, 1, 8, 6, 5, 9, 2, 3, 1, 7, 4, 9, 1, 5, 3, 7, 9, 8])

# %%
ts=pd.Series(np.random.randint(1,10,len(rng)),index=rng)

# %%
ts.head(10)
# Out:
# 2017-01-01    3
# 2017-01-02    9
# 2017-01-03    2
# 2017-01-04    6
# 2017-01-05    3
# 2017-01-06    1
# 2017-01-07    3
# 2017-01-08    1
# 2017-01-09    1
# 2017-01-10    6
# Freq: D, dtype: int64

# %% [markdown]
# date range가 handle하기 어려운건 공휴일! 이건 뒤에서 따로 처리

# %%
rng
# Out:
# DatetimeIndex(['2017-01-01', '2017-01-02', '2017-01-03', '2017-01-04',
#                '2017-01-05', '2017-01-06', '2017-01-07', '2017-01-08',
#                '2017-01-09', '2017-01-10', '2017-01-11', '2017-01-12',
#                '2017-01-13', '2017-01-14', '2017-01-15', '2017-01-16',
#                '2017-01-17', '2017-01-18', '2017-01-19', '2017-01-20',
#                '2017-01-21', '2017-01-22'],
#               dtype='datetime64[ns]', freq='D')

# %%
len(rng)
# Out:
# 22
